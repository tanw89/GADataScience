# %% [markdown]
# # DrivenData Blood Donation Dataset

# %%
#A rather simple dataset. Reading in the csv file.

import numpy as np
import pandas as pd
df = pd.read_csv("C:/Users/tanw/Desktop/Kaggle/BloodDonation/bloodtraindata.csv")
df.head()
# Out:
#    Unnamed: 0  Months since Last Donation  Number of Donations  \
# 0         619                           2                   50
# 1         664                           0                   13
# 2         441                           1                   16
# 3         160                           2                   20
# 4         358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            0

# %%
#Visualise pairplots

import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(data=df, vars=df[1:], hue="Made Donation in March 2007")
plt.show()

# %%
# Feedforward Neural Network
model = Sequential()

# First layer
model.add(Dense(units=8, input_dim=5))
model.add(Activation("tanh"))

model.add(Dense(units=6, input_dim=6))
model.add(Activation("tanh"))

# Output layer - output_dim=# of output per point (in y).
# Use 'softmax' for class probability. 'linear' for regression
model.add(Dense(units=3, input_dim=6))
model.add(Activation("softmax"))

# Uses Mean Squared Error and Stochastic Gradient Descent
model.compile(loss='mse', optimizer=SGD(lr=0.1))
